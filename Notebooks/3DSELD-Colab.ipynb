# %% [markdown]
# # **3D Sound Localization**
# This notebook is meant to be used on Google Colab. This will let you use a pre-loaded data set and cloud GPU computing.
#
# __[IMPORTANT]__ Steps to do:
#
# 1.   Download and upload on your Google Drive (__/content/drive/My Drive/__) our [repository](https://github.com/RickyMexx/3D-Sound-Localization/archive/master.zip).
# 2.   Add the [pre-extracted data set](https://drive.google.com/drive/folders/1-7Kl9GSKYaTLdeSyzdPKhX9Xu_rkOks4?usp=sharing) to your drive and move it to __/content/drive/My Drive/3D_Sound_Localization/__ folder.
# 3.   You're ready to go! Now you can __skip the features extraction at step 3__.

# %% [markdown]
# #### [1] **Google drive mounting**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# #### [2] **Tensorflow-gpu and Keras installation**

# %%
# !pip install tensorflow-gpu==1.13.1
# !pip install keras==2.2.2

# %% [markdown]
# #### [3-__SKIP__] **Extraction of the features**

# %%
# %cd "/content/drive/My Drive/3D_Sound_Localization/Code"
# !python2 batch_feature_extraction.py

# %% [markdown]
# #### [4] **Training of the network**

# %%
# %cd "/content/drive/My Drive/3D_Sound_Localization/Code"
# !python seld.py

# %% [markdown]
# #### [5] **Outcomes plotting**

# %%
# %cd "/content/drive/My Drive/3D_Sound_Localization/Code"
# !python simple_plotter.py "models/foa_train[3, 4]_validation2_seq128_plot.csv"

# %% [markdown]
# #### [6] **Testing the model**

# %%
# %cd "/content/drive/My Drive/3D_Sound_Localization/Code"
# !python seld_test.py
# Out:
# /content/drive/My Drive/3D_Sound_Localization/Code
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# ...
